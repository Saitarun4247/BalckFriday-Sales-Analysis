# %% [markdown]
# # BlackFridaySalesAnalysis

# %% [raw]
#  dataset is taken from the kaggle.com

# %% [markdown]
# importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading the csv file using pandas

# %%
bf=pd.read_csv("BlackFriday.csv")
bf
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
bf.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
bf.tail()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 537572                          1               0                   1
# 537573                          1               0                   1
# 537574                          1               0                   8
# 537575                          1               0                   5
# 537576                          1               0                   5
#
#         Product_Category_2  Product_Category_3  Purchase
# 537572                 2.0                 NaN     11664
# ...

# %%
bf.shape
# Out:
# (537577, 12)

# %%
bf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %% [raw]
# Checking the number of null values

# %%
bf.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %% [raw]
# Cleaning the null values

# %%
bf.dropna().isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
bf.dropna()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 1       1000001  P00248942      F   0-17          10             A
# 6       1000004  P00184942      M  46-50           7             B
# 13      1000005  P00145042      M  26-35          20             A
# 14      1000006  P00231342      F  51-55           9             A
# 16      1000006   P0096642      F  51-55           9             A
# ...         ...        ...    ...    ...         ...           ...
# 537549  1004734  P00345842      M  51-55           1             B
# 537551  1004735  P00313442      M  46-50           3             C
# 537562  1004736  P00146742      M  18-25          20             A
# 537571  1004737  P00221442      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1                               2               0                   1
# ...

# %%
del bf["Product_Category_2"]
del bf['Product_Category_3']

# %%
bf
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [raw]
# Using unique function

# %%
bf['User_ID'].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529],
#       dtype=int64)

# %%
bf["Product_ID"].unique()
# Out:
# array(['P00069042', 'P00248942', 'P00087842', ..., 'P00038842',
#        'P00295642', 'P00091742'], dtype=object)

# %%
bf["Age"].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
bf['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
bf['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
bf['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
bf['Marital_Status'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
bf['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9], dtype=int64)

# %% [raw]
# Total Average user expediture

# %%
bf['Purchase'].sum()/len(bf['Purchase'])
# Out:
# 9333.859852635065

# %% [raw]
# Total Unique according to the columns

# %%
for column in bf.columns:
    print(column,":",bf[column].nunique())
# Out:
# User_ID : 5891
# Product_ID : 3623
# Gender : 2
# Age : 7
# Occupation : 21
# City_Category : 3
# Stay_In_Current_City_Years : 5
# Marital_Status : 2
# Product_Category_1 : 18
# Purchase : 17959

# %% [raw]
# Analysing the Gender

# %%
bf["Gender"]
# Out:
# 0         F
# 1         F
# 2         F
# 3         F
# 4         M
#          ..
# 537572    M
# 537573    M
# 537574    M
# 537575    M
# 537576    M
# Name: Gender, Length: 537577, dtype: object

# %% [raw]
# Total Number of male purchased

# %%
(bf['Gender']=="M").sum()
# Out:
# 405380

# %% [raw]
# Total Number of female purchased

# %%
(bf["Gender"]=='F').sum()
# Out:
# 132197

# %%
data =pd.DataFrame({'Ratio': [(bf['Gender']=="M").sum(),(bf["Gender"]=='F').sum()]},index=["Male","Female"])
data
# Out:
#          Ratio
# Male    405380
# Female  132197

# %%
data.plot.pie(y='Ratio',figsize=(6,6),autopct="%.1f")
plt.show()

# %%
bf.groupby('Gender').size()
# Out:
# Gender
# F    132197
# M    405380
# dtype: int64

# %%
bf.groupby('Gender').size().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Gender'>

# %% [raw]
# Total Amount Spent by the Gender

# %%
bf.groupby('Gender').sum()['Purchase']
# Out:
# Gender
# F    1164624021
# M    3853044357
# Name: Purchase, dtype: int64

# %%
bf.groupby('Gender').sum()['Purchase'].plot(kind="pie",autopct="%0.1f")
# Out:
# <AxesSubplot:ylabel='Purchase'>

# %% [raw]
# Mean Amount spent according to the Gender

# %%
bf.groupby('Gender').mean()['Purchase'].plot(kind="pie",autopct="%0.1f")
# Out:
# <AxesSubplot:ylabel='Purchase'>

# %%
bf.groupby("Age").size()
# Out:
# Age
# 0-17      14707
# 18-25     97634
# 26-35    214690
# 36-45    107499
# 46-50     44526
# 51-55     37618
# 55+       20903
# dtype: int64

# %%
bf.groupby("Age").size().plot(kind='bar',title="Purchase distribution By Age")
# Out:
# <AxesSubplot:title={'center':'Purchase distribution By Age'}, xlabel='Age'>

# %%
lis=[]
for i in bf['Age'].unique():
    lis.append([i,bf[bf['Age']==i]['Product_ID'].nunique()])
data=pd.DataFrame(lis,columns=["Age","Products"])
data
# Out:
#      Age  Products
# 0   0-17      2300
# 1    55+      2573
# 2  26-35      3419
# 3  46-50      3099
# 4  51-55      2877
# 5  36-45      3318
# 6  18-25      3213

# %%
data.plot.bar(x="Age",y="Products")
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
bf.groupby('Age').sum()['Purchase'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
bf.groupby('Age').mean()['Purchase'].plot(kind='pie',autopct="%0.1f")
# Out:
# <AxesSubplot:ylabel='Purchase'>

# %%
bf.groupby('Marital_Status').size().plot(kind='pie',autopct='%0.1f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
bf.groupby('Gender').size().plot(kind='pie',autopct="%0.1f")
# Out:
# <AxesSubplot:ylabel='None'>

# %%
sns.set(rc={'figure.figsize':(12,6)})
sns.countplot(x='Age',hue='Gender',data=bf)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.countplot(x='Gender',hue='Age',data=bf)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x='Gender',hue='Marital_Status',data=bf)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x="City_Category",hue="Age",data=bf)
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='count'>

# %%
bf.groupby('City_Category').size().plot(kind='pie',autopct="%0.1f")
# Out:
# <AxesSubplot:ylabel='None'>

# %%
sns.countplot(x='Marital_Status',hue='Age',data=bf)
# Out:
# <AxesSubplot:xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x="City_Category",hue="Gender",data=bf)
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='count'>

# %%
bf.groupby('City_Category').sum()['Purchase'].plot(kind ='pie',autopct="%0.1f")
# Out:
# <AxesSubplot:ylabel='Purchase'>

# %%
bf.groupby('City_Category').mean()["Purchase"].plot(kind='pie',autopct="%0.1f")
# Out:
# <AxesSubplot:ylabel='Purchase'>

# %%
sns.countplot(x=bf['Stay_In_Current_City_Years'])
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue="Gender",data=bf)
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue="Marital_Status",data=bf)
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue="City_Category",data=bf)
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x="City_Category",hue="Age",data=bf)
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='count'>

# %%
bf.groupby('Stay_In_Current_City_Years').size().plot(kind='pie',autopct="%.1f")
# Out:
# <AxesSubplot:ylabel='None'>

# %%
bf.groupby('Stay_In_Current_City_Years').sum()['Purchase'].plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years'>

# %%
bf.groupby('Stay_In_Current_City_Years').mean()['Purchase'].plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years'>

# %%
sns.countplot(x = bf['Occupation'])
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='count'>

# %%
bf.groupby('Occupation').size().sort_values().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Occupation'>

# %%
bf.groupby('Occupation').sum()['Purchase'].sort_values().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Occupation'>

# %%
bf.groupby('Occupation').mean()['Purchase'].sort_values().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Occupation'>

# %%
sns.countplot(x = 'Occupation', hue = 'Marital_Status', data = bf)
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x = 'Occupation', hue = 'Gender', data = bf)
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='count'>

# %%
bf.groupby('Occupation').nunique()['Product_ID'].plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Occupation'>

# %%
sns.countplot(x = 'Product_Category_1', hue = 'Gender', data = bf)
# Out:
# <AxesSubplot:xlabel='Product_Category_1', ylabel='count'>

# %%
l = []
for i in range(len(bf)):
    l.append(bf['Gender'][i] +"_"+ str(bf['Marital_Status'][i]))

bf['MaritalGender'] = l

sns.countplot(x = bf['MaritalGender'])
# Out:
# <AxesSubplot:xlabel='MaritalGender', ylabel='count'>

# %%
sns.countplot(x = bf['Age'], hue = bf['MaritalGender'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.countplot(x = bf['Product_Category_1'], hue = bf['MaritalGender'])
# Out:
# <AxesSubplot:xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x = bf['Stay_In_Current_City_Years'], hue = bf['MaritalGender'])
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = bf['City_Category'], hue = bf['MaritalGender'])
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='count'>

# %%
sns.pairplot(bf)

# %%
sns.heatmap(bf.corr(),square=True,cmap="Greys")
# Out:
# <AxesSubplot:>
